# %% [markdown]
# # CropGuard AI — 01 Exploratory Data Analysis
# **NASTP Institute of Information Technology | AI335L — Deep Learning Lab | Spring 2026**
#
# Covers:
# 1. Dataset inventory and class distribution
# 2. Representative sample images
# 3. RGB channel analysis
# 4. Blur/quality filtering (Laplacian variance)
# 5. PCA and t-SNE feature-space visualisation
#
# **Key finding:** Potato Healthy class has only 152 images — a 12.6× imbalance vs the majority class (Tomato Late Blight, 1,909 images). This motivates the VAE augmentation in Phase 4.

# %%
# !pip install torch==2.1.2
# !pip install torchvision==0.16.2
# !pip install torchaudio==2.1.2

# !pip install pytorch-grad-cam==1.4.8

# !pip install scikit-learn==1.4.0
# !pip install numpy==1.26.4
# !pip install pandas==2.2.0
# !pip install scipy==1.12.0
# !pip install statsmodels==0.14.1

# !pip install opencv-python-headless==4.9.0.80
# !pip install Pillow==10.2.0

# !pip install matplotlib==3.8.2
# !pip install seaborn==0.13.2
# !pip install plotly==5.18.0

# !pip install streamlit==1.31.0
# !pip install watchdog==3.0.0

# !pip install optuna==3.5.0

# !pip install thop==0.1.1.post2209072238

# !pip install torchinfo==1.8.0

# !pip install tqdm==4.66.2
# !pip install python-dotenv==1.0.1
# Out:
# Collecting torch==2.1.2
#   Downloading torch-2.1.2-cp310-cp310-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2) (3.29.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2) (4.15.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2) (1.13.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2) (3.4.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2) (3.1.6)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2) (2026.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from jinja2->torch==2.1.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from sympy->torch==2.1.2) (1.3.0)
# Downloading torch-2.1.2-cp310-cp310-win_amd64.whl (192.3 MB)
#    ---------------------------------------- 0.0/192.3 MB ? eta -:--:--
#    ------- ------------------------------- 36.2/192.3 MB 191.0 MB/s eta 0:00:01
#    ------------- ------------------------- 64.2/192.3 MB 163.6 MB/s eta 0:00:01
#    -------------------- ------------------ 99.1/192.3 MB 166.4 MB/s eta 0:00:01
#    -------------------------- ----------- 136.3/192.3 MB 170.7 MB/s eta 0:00:01
#    ---------------------------------- --- 175.4/192.3 MB 175.1 MB/s eta 0:00:01
#    -------------------------------------  192.2/192.3 MB 175.4 MB/s eta 0:00:01
#    -------------------------------------  192.2/192.3 MB 175.4 MB/s eta 0:00:01
#    ---------------------------------------- 192.3/192.3 MB 121.7 MB/s  0:00:01
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
# Successfully installed torch-2.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1+cu121, but you have torch 2.1.2 which is incompatible.
# torchvision 0.20.1+cu121 requires torch==2.5.1+cu121, but you have torch 2.1.2 which is incompatible.
# Collecting torchvision==0.16.2
#   Downloading torchvision-0.16.2-cp310-cp310-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torchvision==0.16.2) (2.2.6)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torchvision==0.16.2) (2.33.1)
# Requirement already satisfied: torch==2.1.2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torchvision==0.16.2) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torchvision==0.16.2) (12.2.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchvision==0.16.2) (3.29.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchvision==0.16.2) (4.15.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchvision==0.16.2) (1.13.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchvision==0.16.2) (3.4.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchvision==0.16.2) (3.1.6)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchvision==0.16.2) (2026.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from jinja2->torch==2.1.2->torchvision==0.16.2) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from requests->torchvision==0.16.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from requests->torchvision==0.16.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from requests->torchvision==0.16.2) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from requests->torchvision==0.16.2) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from sympy->torch==2.1.2->torchvision==0.16.2) (1.3.0)
# Downloading torchvision-0.16.2-cp310-cp310-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 28.3 MB/s  0:00:00
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
# Successfully installed torchvision-0.16.2
# Collecting torchaudio==2.1.2
#   Downloading torchaudio-2.1.2-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: torch==2.1.2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torchaudio==2.1.2) (2.1.2)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchaudio==2.1.2) (3.29.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchaudio==2.1.2) (4.15.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchaudio==2.1.2) (1.13.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchaudio==2.1.2) (3.4.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchaudio==2.1.2) (3.1.6)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch==2.1.2->torchaudio==2.1.2) (2026.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from jinja2->torch==2.1.2->torchaudio==2.1.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from sympy->torch==2.1.2->torchaudio==2.1.2) (1.3.0)
# Downloading torchaudio-2.1.2-cp310-cp310-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 33.2 MB/s  0:00:00
# Installing collected packages: torchaudio
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.5.1+cu121
#     Uninstalling torchaudio-2.5.1+cu121:
#       Successfully uninstalled torchaudio-2.5.1+cu121
# Successfully installed torchaudio-2.1.2
# ERROR: Could not find a version that satisfies the requirement pytorch-grad-cam==1.4.8 (from versions: none)
# ERROR: No matching distribution found for pytorch-grad-cam==1.4.8
# Collecting scikit-learn==1.4.0
#   Downloading scikit_learn-1.4.0-1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting numpy<2.0,>=1.19.5 (from scikit-learn==1.4.0)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting scipy>=1.6.0 (from scikit-learn==1.4.0)
#   Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn==1.4.0)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn==1.4.0)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.0-1-cp310-cp310-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 10.6/10.6 MB 132.2 MB/s  0:00:00
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 15.8/15.8 MB 142.6 MB/s  0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    -------------------------------- ------- 33.6/41.3 MB 177.1 MB/s eta 0:00:01
#    ---------------------------------------- 41.3/41.3 MB 119.2 MB/s  0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.2.6
#
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#     Uninstalling numpy-2.2.6:
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#       Successfully uninstalled numpy-2.2.6
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    ---------------------------------------- 5/5 [scikit-learn]
#
# Successfully installed joblib-1.5.3 numpy-1.26.4 scikit-learn-1.4.0 scipy-1.15.3 threadpoolctl-3.6.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\ProgramData\anaconda3\envs\gpu_env\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\ProgramData\anaconda3\envs\gpu_env\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# Requirement already satisfied: numpy==1.26.4 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (1.26.4)
# Collecting pandas==2.2.0
#   Downloading pandas-2.2.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas==2.2.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas==2.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas==2.2.0) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas==2.2.0) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.0) (1.17.0)
# Downloading pandas-2.2.0-cp310-cp310-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    -------------------------------------- - 11.0/11.6 MB 62.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 60.5 MB/s  0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.3
#     Uninstalling pandas-2.3.3:
#       Successfully uninstalled pandas-2.3.3
# Successfully installed pandas-2.2.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\ProgramData\anaconda3\envs\gpu_env\Lib\site-packages\~andas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\ProgramData\anaconda3\envs\gpu_env\Lib\site-packages\~andas'.
#   You can safely remove it manually.
# Collecting scipy==1.12.0
#   Downloading scipy-1.12.0-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from scipy==1.12.0) (1.26.4)
# Downloading scipy-1.12.0-cp310-cp310-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ------------------ --------------------- 21.5/46.2 MB 112.9 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 139.4 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 108.8 MB/s  0:00:00
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
# Successfully installed scipy-1.12.0
# Collecting statsmodels==0.14.1
#   Downloading statsmodels-0.14.1-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy<2,>=1.18 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from statsmodels==0.14.1) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from statsmodels==0.14.1) (1.12.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from statsmodels==0.14.1) (2.2.0)
# Collecting patsy>=0.5.4 (from statsmodels==0.14.1)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from statsmodels==0.14.1) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels==0.14.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels==0.14.1) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels==0.14.1) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.0->statsmodels==0.14.1) (1.17.0)
# Downloading statsmodels-0.14.1-cp310-cp310-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 9.8/9.8 MB 55.7 MB/s  0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
#
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    ---------------------------------------- 2/2 [statsmodels]
#
# Successfully installed patsy-1.0.2 statsmodels-0.14.1
# Collecting opencv-python-headless==4.9.0.80
#   Downloading opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from opencv-python-headless==4.9.0.80) (1.26.4)
# Downloading opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    --------------------------- ------------ 26.2/38.5 MB 138.8 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 116.7 MB/s  0:00:00
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.9.0.80
# Collecting Pillow==10.2.0
#   Downloading pillow-10.2.0-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Downloading pillow-10.2.0-cp310-cp310-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 50.2 MB/s  0:00:00
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 12.2.0
#     Uninstalling pillow-12.2.0:
#       Successfully uninstalled pillow-12.2.0
# Successfully installed Pillow-10.2.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\ProgramData\anaconda3\envs\gpu_env\Lib\site-packages\~il'.
#   You can safely remove it manually.
# Collecting matplotlib==3.8.2
#   Downloading matplotlib-3.8.2-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib==3.8.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib==3.8.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib==3.8.2) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib==3.8.2) (1.5.0)
# Requirement already satisfied: numpy<2,>=1.21 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib==3.8.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib==3.8.2) (26.0)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib==3.8.2) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib==3.8.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib==3.8.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.8.2) (1.17.0)
# Downloading matplotlib-3.8.2-cp310-cp310-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 7.6/7.6 MB 67.7 MB/s  0:00:00
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.9
#     Uninstalling matplotlib-3.10.9:
#       Successfully uninstalled matplotlib-3.10.9
# Successfully installed matplotlib-3.8.2
#   WARNING: Failed to remove contents in a temporary directory 'C:\ProgramData\anaconda3\envs\gpu_env\Lib\site-packages\~atplotlib'.
#   You can safely remove it manually.
# Requirement already satisfied: seaborn==0.13.2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from seaborn==0.13.2) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from seaborn==0.13.2) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from seaborn==0.13.2) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (26.0)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.17.0)
# Collecting plotly==5.18.0
#   Downloading plotly-5.18.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting tenacity>=6.2.0 (from plotly==5.18.0)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from plotly==5.18.0) (26.0)
# Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 15.6/15.6 MB 98.0 MB/s  0:00:00
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
#
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    ---------------------------------------- 2/2 [plotly]
#
# Successfully installed plotly-5.18.0 tenacity-9.1.4
# Collecting streamlit==1.31.0
#   Downloading streamlit-1.31.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting altair<6,>=4.0 (from streamlit==1.31.0)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit==1.31.0)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit==1.31.0)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9,>=7.0 (from streamlit==1.31.0)
#   Downloading click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting importlib-metadata<8,>=1.4 (from streamlit==1.31.0)
#   Downloading importlib_metadata-7.2.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from streamlit==1.31.0) (1.26.4)
# Collecting packaging<24,>=16.8 (from streamlit==1.31.0)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from streamlit==1.31.0) (2.2.0)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from streamlit==1.31.0) (10.2.0)
# Collecting protobuf<5,>=3.20 (from streamlit==1.31.0)
#   Downloading protobuf-4.25.9-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting pyarrow>=7.0 (from streamlit==1.31.0)
#   Downloading pyarrow-24.0.0-cp310-cp310-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from streamlit==1.31.0) (2.9.0.post0)
# Requirement already satisfied: requests<3,>=2.27 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from streamlit==1.31.0) (2.33.1)
# Collecting rich<14,>=10.14.0 (from streamlit==1.31.0)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9,>=8.1.0 (from streamlit==1.31.0)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit==1.31.0)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from streamlit==1.31.0) (4.15.0)
# Collecting tzlocal<6,>=1.1 (from streamlit==1.31.0)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting validators<1,>=0.2 (from streamlit==1.31.0)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit==1.31.0)
#   Downloading gitpython-3.1.50-py3-none-any.whl.metadata (14 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit==1.31.0)
#   Downloading pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from streamlit==1.31.0) (6.5.5)
# Collecting watchdog>=2.1.5 (from streamlit==1.31.0)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.0) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.0) (4.25.1)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit==1.31.0)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from click<9,>=7.0->streamlit==1.31.0) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.31.0)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.31.0)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting zipp>=0.5 (from importlib-metadata<8,>=1.4->streamlit==1.31.0)
#   Downloading zipp-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas<3,>=1.3.0->streamlit==1.31.0) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from pandas<3,>=1.3.0->streamlit==1.31.0) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit==1.31.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from requests<3,>=2.27->streamlit==1.31.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from requests<3,>=2.27->streamlit==1.31.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from requests<3,>=2.27->streamlit==1.31.0) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from requests<3,>=2.27->streamlit==1.31.0) (2026.4.22)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit==1.31.0)
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.31.0) (2.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit==1.31.0) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.0) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.0) (0.28.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.31.0)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading streamlit-1.31.0-py2.py3-none-any.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 8.4/8.4 MB 172.6 MB/s  0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 29.3 MB/s  0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading click-8.4.1-py3-none-any.whl (116 kB)
# Downloading gitpython-3.1.50-py3-none-any.whl (212 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading importlib_metadata-7.2.1-py3-none-any.whl (25 kB)
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
# Downloading protobuf-4.25.9-cp310-abi3-win_amd64.whl (413 kB)
# Downloading pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 11.3/11.3 MB 141.6 MB/s  0:00:00
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
# Downloading pyarrow-24.0.0-cp310-cp310-win_amd64.whl (27.3 MB)
#    ---------------------------------------- 0.0/27.3 MB ? eta -:--:--
#    ---------------------------------------  27.0/27.3 MB 142.2 MB/s eta 0:00:01
#    ---------------------------------------- 27.3/27.3 MB 114.8 MB/s  0:00:00
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading zipp-4.1.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, watchdog, validators, tzlocal, toml, tenacity, smmap, pyarrow, protobuf, packaging, narwhals, mdurl, click, cachetools, blinker, pydeck, markdown-it-py, importlib-metadata, gitdb, rich, gitpython, altair, streamlit
#
#    --- ------------------------------------  2/23 [validators]
#   Attempting uninstall: tenacity
#    --- ------------------------------------  2/23 [validators]
#     Found existing installation: tenacity 9.1.4
#    --- ------------------------------------  2/23 [validators]
#     Uninstalling tenacity-9.1.4:
#    --- ------------------------------------  2/23 [validators]
#       Successfully uninstalled tenacity-9.1.4
#    --- ------------------------------------  2/23 [validators]
#    -------- -------------------------------  5/23 [tenacity]
#    ------------ ---------------------------  7/23 [pyarrow]
#    ------------ ---------------------------  7/23 [pyarrow]
#    ------------ ---------------------------  7/23 [pyarrow]
#    ------------ ---------------------------  7/23 [pyarrow]
#    ------------ ---------------------------  7/23 [pyarrow]
#    ------------ ---------------------------  7/23 [pyarrow]
#    ------------ ---------------------------  7/23 [pyarrow]
#    ------------ ---------------------------  7/23 [pyarrow]
#   Attempting uninstall: protobuf
#    ------------ ---------------------------  7/23 [pyarrow]
#     Found existing installation: protobuf 7.34.1
#    ------------ ---------------------------  7/23 [pyarrow]
#     Uninstalling protobuf-7.34.1:
#    ------------ ---------------------------  7/23 [pyarrow]
#       Successfully uninstalled protobuf-7.34.1
#    ------------ ---------------------------  7/23 [pyarrow]
#    ------------- --------------------------  8/23 [protobuf]
#    ------------- --------------------------  8/23 [protobuf]
#   Attempting uninstall: packaging
#    ------------- --------------------------  8/23 [protobuf]
#     Found existing installation: packaging 26.0
#    ------------- --------------------------  8/23 [protobuf]
#     Uninstalling packaging-26.0:
#    ------------- --------------------------  8/23 [protobuf]
#       Successfully uninstalled packaging-26.0
#    ------------- --------------------------  8/23 [protobuf]
#    ----------------- ---------------------- 10/23 [narwhals]
#    ----------------- ---------------------- 10/23 [narwhals]
#    ----------------- ---------------------- 10/23 [narwhals]
#    ----------------- ---------------------- 10/23 [narwhals]
#    ------------------------ --------------- 14/23 [blinker]
#    -------------------------- ------------- 15/23 [pydeck]
#    --------------------------- ------------ 16/23 [markdown-it-py]
#    ------------------------------- -------- 18/23 [gitdb]
#    --------------------------------- ------ 19/23 [rich]
#    ---------------------------------- ----- 20/23 [gitpython]
#    ------------------------------------ --- 21/23 [altair]
#    ------------------------------------ --- 21/23 [altair]
#    -------------------------------------- - 22/23 [streamlit]
#    -------------------------------------- - 22/23 [streamlit]
#    -------------------------------------- - 22/23 [streamlit]
#    -------------------------------------- - 22/23 [streamlit]
#    -------------------------------------- - 22/23 [streamlit]
#    ---------------------------------------- 23/23 [streamlit]
#
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-5.5.2 click-8.4.1 gitdb-4.0.12 gitpython-3.1.50 importlib-metadata-7.2.1 markdown-it-py-4.2.0 mdurl-0.1.2 narwhals-2.22.1 packaging-23.2 protobuf-4.25.9 pyarrow-24.0.0 pydeck-0.9.2 rich-13.9.4 smmap-5.0.3 streamlit-1.31.0 tenacity-8.5.0 toml-0.10.2 tzlocal-5.3.1 validators-0.35.0 watchdog-6.0.0 zipp-4.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wheel 0.46.3 requires packaging>=24.0, but you have packaging 23.2 which is incompatible.
# Collecting watchdog==3.0.0
#   Downloading watchdog-3.0.0-py3-none-win_amd64.whl.metadata (36 kB)
# Downloading watchdog-3.0.0-py3-none-win_amd64.whl (82 kB)
# Installing collected packages: watchdog
#   Attempting uninstall: watchdog
#     Found existing installation: watchdog 6.0.0
#     Uninstalling watchdog-6.0.0:
#       Successfully uninstalled watchdog-6.0.0
# Successfully installed watchdog-3.0.0
# Collecting optuna==3.5.0
#   Downloading optuna-3.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna==3.5.0)
#   Downloading alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna==3.5.0)
#   Using cached colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from optuna==3.5.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from optuna==3.5.0) (23.2)
# Collecting sqlalchemy>=1.3.0 (from optuna==3.5.0)
#   Downloading sqlalchemy-2.0.50-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from optuna==3.5.0) (4.67.3)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from optuna==3.5.0) (6.0.3)
# Collecting Mako (from alembic>=1.5.0->optuna==3.5.0)
#   Downloading mako-1.3.12-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.12 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from alembic>=1.5.0->optuna==3.5.0) (4.15.0)
# Requirement already satisfied: tomli in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from alembic>=1.5.0->optuna==3.5.0) (2.4.0)
# Collecting greenlet>=1 (from sqlalchemy>=1.3.0->optuna==3.5.0)
#   Downloading greenlet-3.5.1-cp310-cp310-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from colorlog->optuna==3.5.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from Mako->alembic>=1.5.0->optuna==3.5.0) (3.0.2)
# Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
# Downloading alembic-1.18.4-py3-none-any.whl (263 kB)
# Downloading sqlalchemy-2.0.50-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 29.9 MB/s  0:00:00
# Downloading greenlet-3.5.1-cp310-cp310-win_amd64.whl (237 kB)
# Using cached colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading mako-1.3.12-py3-none-any.whl (78 kB)
# Installing collected packages: Mako, greenlet, colorlog, sqlalchemy, alembic, optuna
#
#    ------ --------------------------------- 1/6 [greenlet]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [alembic]
#    --------------------------------- ------ 5/6 [optuna]
#    --------------------------------- ------ 5/6 [optuna]
#    --------------------------------- ------ 5/6 [optuna]
#    --------------------------------- ------ 5/6 [optuna]
#    ---------------------------------------- 6/6 [optuna]
#
# Successfully installed Mako-1.3.12 alembic-1.18.4 colorlog-6.10.1 greenlet-3.5.1 optuna-3.5.0 sqlalchemy-2.0.50
# Collecting thop==0.1.1.post2209072238
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from thop==0.1.1.post2209072238) (2.1.2)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch->thop==0.1.1.post2209072238) (3.29.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch->thop==0.1.1.post2209072238) (4.15.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch->thop==0.1.1.post2209072238) (1.13.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch->thop==0.1.1.post2209072238) (3.4.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch->thop==0.1.1.post2209072238) (3.1.6)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from torch->thop==0.1.1.post2209072238) (2026.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from jinja2->torch->thop==0.1.1.post2209072238) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from sympy->torch->thop==0.1.1.post2209072238) (1.3.0)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238
# Collecting torchinfo==1.8.0
#   Using cached torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Using cached torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# Collecting tqdm==4.66.2
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\gpu_env\lib\site-packages (from tqdm==4.66.2) (0.4.6)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.3
#     Uninstalling tqdm-4.67.3:
#       Successfully uninstalled tqdm-4.67.3
# Successfully installed tqdm-4.66.2
# Collecting python-dotenv==1.0.1
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from PIL import Image
from tqdm import tqdm
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

from src.utils import (
    TARGET_CLASSES, CLASS_DISPLAY, IMAGENET_MEAN, IMAGENET_STD,
    laplacian_variance, set_seed, BLUR_THRESH,
)

set_seed(42)
plt.rcParams.update({'figure.dpi': 120, 'font.family': 'DejaVu Sans'})
PALETTE = plt.cm.tab10.colors
print('Imports OK')
# Out:
# Imports OK

# %%
# ── Configuration ─────────────────────────────────────────────────────────────
DATA_ROOT = Path('../data/raw')       # ← Update to your PlantVillage colour folder
OUT_DIR   = Path('../data/processed')
OUT_DIR.mkdir(parents=True, exist_ok=True)

SEED     = 42
N_SAMPLE = 80    # images per class for channel stats
N_VIS    = 120   # images per class for PCA/t-SNE
MLP_SIZE = 32    # flatten resolution for PCA features
PCA_N    = 50

print(f'Data root: {DATA_ROOT}')
# Out:
# Data root: ..\data\raw

# %% [markdown]
# ## 1. Dataset Inventory

# %%
records = []
for cls_dir in sorted(DATA_ROOT.iterdir()):
    if cls_dir.is_dir() and cls_dir.name in TARGET_CLASSES:
        for img_path in cls_dir.glob('*'):
            if img_path.suffix.lower() in ('.jpg', '.jpeg', '.png'):
                records.append({'path': str(img_path), 'class': cls_dir.name})

df = pd.DataFrame(records)
name_map = dict(zip(TARGET_CLASSES, CLASS_DISPLAY))
df['class_display'] = df['class'].map(name_map)
class_counts = df['class_display'].value_counts().reindex(CLASS_DISPLAY)

total = len(df)
imbalance = class_counts.max() / class_counts.min()

print(f'Total images  : {total:,}')
print(f'Classes       : {len(TARGET_CLASSES)}')
print(f'Imbalance ratio: {imbalance:.1f}× '
      f'({class_counts.idxmin()}: {class_counts.min():,} vs '
      f'{class_counts.idxmax()}: {class_counts.max():,})')
print()
for cls, cnt in class_counts.items():
    flag = '  ⚠️  CRITICAL' if cls == 'Potato Healthy' else ''
    print(f'  {cls:<30}  {cnt:5,}  ({cnt/total*100:5.2f}%){flag}')
# Out:
# Total images  : 11,481
# Classes       : 10
# Imbalance ratio: 12.6× (Potato Healthy: 152 vs Tomato Late Blight: 1,909)
#
#   Tomato Early Blight             1,000  ( 8.71%)
#   Tomato Late Blight              1,909  (16.63%)
#   Tomato Healthy                  1,591  (13.86%)
#   Potato Early Blight             1,000  ( 8.71%)
#   Potato Late Blight              1,000  ( 8.71%)
#   Potato Healthy                    152  ( 1.32%)  ⚠️  CRITICAL
#   Pepper Bacterial Spot             997  ( 8.68%)
#   Pepper Healthy                  1,478  (12.87%)
#   Corn Common Rust                1,192  (10.38%)
#   Corn Healthy                    1,162  (10.12%)

# %% [markdown]
# ## 2. Class Distribution Visualisation

# %%
counts = [class_counts[c] for c in CLASS_DISPLAY]
colours = ['#e74c3c' if c == 'Potato Healthy'
           else f'#{(50+i*20)%255:02x}{(100+i*15)%255:02x}{(80+i*18)%255:02x}'
           for i, c in enumerate(CLASS_DISPLAY)]

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
fig.suptitle('Figure 1 — PlantVillage 10-Class Distribution', fontsize=14, fontweight='bold')

axes[0].barh(CLASS_DISPLAY, counts, color=colours, edgecolor='white', linewidth=0.5)
axes[0].set_xlabel('Number of Images')
axes[0].set_title('Class Distribution (Horizontal Bar)', fontweight='bold')
for i, v in enumerate(counts):
    axes[0].text(v + 10, i, f'{v:,}', va='center', fontsize=8)
axes[0].set_xlim(0, max(counts) * 1.15)
axes[0].invert_yaxis()

explode = [0.08 if c == 'Potato Healthy' else 0.0 for c in CLASS_DISPLAY]
wedges, _, autotexts = axes[1].pie(
    counts, labels=None, colors=colours, explode=explode,
    autopct='%1.1f%%', startangle=140,
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.2})
for at in autotexts: at.set_fontsize(7)
axes[1].set_title('Class Proportions (Pie Chart)', fontweight='bold')
axes[1].legend(wedges, CLASS_DISPLAY, loc='lower left',
               bbox_to_anchor=(-0.35, -0.2), fontsize=7, ncol=2)

fig.text(0.5, -0.02,
         f'⚠️  Imbalance: Potato Healthy ({class_counts.min():,}) '
         f'vs Tomato Late Blight ({class_counts.max():,}) — Ratio: {imbalance:.1f}×',
         ha='center', fontsize=9, color='red', fontweight='bold')

plt.tight_layout()
plt.savefig(OUT_DIR / 'fig1_class_distribution.png', bbox_inches='tight', dpi=150)
plt.show()
print(f'Saved to {OUT_DIR}/fig1_class_distribution.png')
# Out:
# Saved to ..\data\processed/fig1_class_distribution.png

# %% [markdown]
# ## 3. Representative Sample Images

# %%
fig, axes = plt.subplots(2, 5, figsize=(18, 8))
fig.suptitle('Figure 2 — Representative Leaf Images per Class', fontsize=14, fontweight='bold')

for ax, cls_name, disp in zip(axes.flat, TARGET_CLASSES, CLASS_DISPLAY):
    cls_df = df[df['class'] == cls_name]
    img_path = cls_df.sample(1, random_state=SEED)['path'].values[0]
    img = Image.open(img_path).convert('RGB').resize((224, 224))
    ax.imshow(img)
    ax.set_title(disp, fontsize=8, fontweight='bold')
    ax.axis('off')

plt.tight_layout()
plt.savefig(OUT_DIR / 'fig2_sample_images.png', bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# ## 4. Quality Filter — Laplacian Variance

# %%
print(f'Applying quality filter (threshold = {BLUR_THRESH})...')
lap_scores = [laplacian_variance(p) for p in tqdm(df['path'], desc='Laplacian filter')]
df['laplacian'] = lap_scores
df_clean = df[df['laplacian'] >= BLUR_THRESH].copy()
removed = len(df) - len(df_clean)

print(f'Original : {len(df):,}')
print(f'Removed  : {removed:,}  ({removed/len(df)*100:.1f}%)')
print(f'Retained : {len(df_clean):,}')

# Distribution of Laplacian scores
fig, ax = plt.subplots(figsize=(10, 4))
ax.hist(df['laplacian'].clip(0, 500), bins=60, color='#3498db', alpha=0.7)
ax.axvline(BLUR_THRESH, color='red', linestyle='--', linewidth=2,
           label=f'Threshold = {BLUR_THRESH}')
ax.set_xlabel('Laplacian Variance')
ax.set_ylabel('Count')
ax.set_title('Image Sharpness Distribution (Laplacian Variance)')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# Applying quality filter (threshold = 50.0)...
# Laplacian filter: 100%|█████████████████████████████████████████████████████████| 11481/11481 [00:22<00:00, 509.90it/s]
# Original : 11,481
# Removed  : 149  (1.3%)
# Retained : 11,332

# %% [markdown]
# ## 5. RGB Channel Analysis

# %%
channel_stats = []
for cls_name, disp in zip(TARGET_CLASSES, CLASS_DISPLAY):
    cls_rows = df_clean[df_clean['class'] == cls_name]
    sample_paths = cls_rows.sample(
        min(N_SAMPLE, len(cls_rows)), random_state=SEED
    )['path'].tolist()
    for path in sample_paths:
        try:
            img = np.array(
                Image.open(path).convert('RGB').resize((64, 64)),
                dtype=np.float32
            ) / 255.0
            channel_stats.append({
                'class': disp,
                'R': img[:, :, 0].mean(),
                'G': img[:, :, 1].mean(),
                'B': img[:, :, 2].mean(),
                'brightness': img.mean(),
            })
        except Exception:
            pass

ch_df = pd.DataFrame(channel_stats)
ch_means = ch_df.groupby('class')[['R', 'G', 'B']].mean().reindex(CLASS_DISPLAY)
print('Channel Statistics:')
print(ch_means.round(4))
# Out:
# Channel Statistics:
#                             R       G       B
# class
# Tomato Early Blight    0.4221  0.4378  0.3883
# Tomato Late Blight     0.4424  0.4495  0.3982
# Tomato Healthy         0.4505  0.4707  0.4355
# Potato Early Blight    0.5319  0.5530  0.4545
# Potato Late Blight     0.4576  0.4664  0.4147
# Potato Healthy         0.4878  0.5181  0.4388
# Pepper Bacterial Spot  0.4716  0.4826  0.3932
# Pepper Healthy         0.4819  0.5302  0.4466
# Corn Common Rust       0.3553  0.3807  0.2723
# Corn Healthy           0.5123  0.6445  0.4714

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 6))
fig.suptitle('Figure 3 — RGB Channel Analysis', fontsize=14, fontweight='bold')

x = np.arange(len(CLASS_DISPLAY)); w = 0.25
axes[0].bar(x - w, ch_means['R'], w, label='R', color='#e74c3c', alpha=0.85)
axes[0].bar(x,     ch_means['G'], w, label='G', color='#27ae60', alpha=0.85)
axes[0].bar(x + w, ch_means['B'], w, label='B', color='#2980b9', alpha=0.85)
axes[0].set_xticks(x)
axes[0].set_xticklabels(CLASS_DISPLAY, rotation=45, ha='right', fontsize=8)
axes[0].set_ylabel('Mean Pixel Value (0–1)')
axes[0].set_title('Mean RGB Channel Values per Class')
axes[0].legend()

sns.violinplot(data=ch_df, x='class', y='brightness', ax=axes[1],
               order=CLASS_DISPLAY, palette='tab10', inner='quartile', cut=0)
axes[1].set_xticklabels(CLASS_DISPLAY, rotation=45, ha='right', fontsize=8)
axes[1].set_ylabel('Mean Brightness')
axes[1].set_title('Brightness Distribution per Class (Violin Plot)')

plt.tight_layout()
plt.savefig(OUT_DIR / 'fig3_channel_analysis.png', bbox_inches='tight', dpi=150)
plt.show()
# Out:
# C:\Users\rendering_lab-07\AppData\Local\Temp\ipykernel_14084\3251485508.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=ch_df, x='class', y='brightness', ax=axes[1],
# C:\Users\rendering_lab-07\AppData\Local\Temp\ipykernel_14084\3251485508.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(CLASS_DISPLAY, rotation=45, ha='right', fontsize=8)

# %% [markdown]
# ## 6. PCA & t-SNE Feature Space Visualisation

# %%
vis_X, vis_y = [], []
print('Loading images for PCA/t-SNE...')
for label, (cls_name, disp) in enumerate(zip(TARGET_CLASSES, CLASS_DISPLAY)):
    cls_rows = df_clean[df_clean['class'] == cls_name]
    sample_df = cls_rows.sample(min(N_VIS, len(cls_rows)), random_state=SEED)
    for path in tqdm(sample_df['path'], desc=disp, leave=False):
        try:
            img = np.array(
                Image.open(path).convert('RGB').resize((MLP_SIZE, MLP_SIZE)),
                dtype=np.float32
            ) / 255.0
            vis_X.append(img.flatten())
            vis_y.append(label)
        except Exception:
            pass

vis_X = np.array(vis_X); vis_y = np.array(vis_y)
print(f'Feature matrix: {vis_X.shape}')

scaler   = StandardScaler()
vis_Xs   = scaler.fit_transform(vis_X)
pca_full = PCA(random_state=SEED).fit(vis_Xs)
cumvar   = np.cumsum(pca_full.explained_variance_ratio_)

pca50   = PCA(n_components=PCA_N, random_state=SEED)
vis_Xp  = pca50.fit_transform(vis_Xs)
var50   = pca50.explained_variance_ratio_.sum() * 100
print(f'PCA-{PCA_N} variance retained: {var50:.1f}%')

print('Running t-SNE (may take 1–2 min)...')
tsne   = TSNE(n_components=2, perplexity=40, n_iter=1000, random_state=SEED)
vis_Xt = tsne.fit_transform(vis_Xp)
print('t-SNE complete.')
# Out:
# Loading images for PCA/t-SNE...
# Feature matrix: (1200, 3072)
# PCA-50 variance retained: 82.6%
# Running t-SNE (may take 1–2 min)...
# t-SNE complete.

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 7))
fig.suptitle('Figure 4 — PCA & t-SNE Feature Space Visualisation',
             fontsize=14, fontweight='bold')

for lbl, disp, col in zip(range(10), CLASS_DISPLAY, PALETTE):
    mask = vis_y == lbl
    axes[0].scatter(vis_Xt[mask, 0], vis_Xt[mask, 1],
                    c=[col], label=disp, alpha=0.65, s=18, edgecolors='none')
axes[0].set_title(f't-SNE 2D Projection (PCA-{PCA_N} features, {var50:.1f}% var)')
axes[0].set_xlabel('t-SNE Dim 1'); axes[0].set_ylabel('t-SNE Dim 2')
axes[0].legend(fontsize=7, markerscale=1.5, loc='upper right')

axes[1].plot(range(1, len(cumvar) + 1), cumvar * 100, color='#2980b9', linewidth=2)
axes[1].axvline(PCA_N, color='red', linestyle='--', linewidth=1.5,
                label=f'n={PCA_N} → {var50:.1f}% variance')
axes[1].axhline(var50, color='red', linestyle=':', linewidth=1.2)
axes[1].fill_between(range(1, PCA_N + 1), cumvar[:PCA_N] * 100,
                     alpha=0.15, color='#e74c3c')
axes[1].set_xlabel('Number of PCA Components')
axes[1].set_ylabel('Cumulative Explained Variance (%)')
axes[1].set_title('PCA Cumulative Variance Curve')
axes[1].set_xlim(1, min(200, len(cumvar)))
axes[1].legend(fontsize=10)

plt.tight_layout()
plt.savefig(OUT_DIR / 'fig4_pca_tsne.png', bbox_inches='tight', dpi=150)
plt.show()

# %%
print('=' * 60)
print('  EDA SUMMARY')
print('=' * 60)
print(f'  Total images       : {total:,}')
print(f'  After quality filter: {len(df_clean):,}')
print(f'  Imbalance ratio    : {imbalance:.1f}×')
print(f'  PCA-{PCA_N} variance   : {var50:.1f}%')
print(f'  Minority class     : Potato Healthy ({class_counts.min():,} images)')
print()
print('  Saved figures to', OUT_DIR)
print('  → Proceed to 02_MLP_Baseline.ipynb')
# Out:
# ============================================================
#   EDA SUMMARY
# ============================================================
#   Total images       : 11,481
#   After quality filter: 11,332
#   Imbalance ratio    : 12.6×
#   PCA-50 variance   : 82.6%
#   Minority class     : Potato Healthy (152 images)
#
#   Saved figures to ..\data\processed
#   → Proceed to 02_MLP_Baseline.ipynb
